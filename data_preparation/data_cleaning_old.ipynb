# %% [markdown]
# ### Import dependencies

# %%
import os
import pandas as pd

# %%
data_dir = os.getcwd()

# %%
bio_data_path = f'{data_dir}/transfermarkt/data_transfermarktver4.csv'
bio_data = pd.read_csv(bio_data_path)
bio_data.head()
# Out:
#    playerId                   name              contractUntil  teamId  \
# 0    561613            Joan García  2031-06-30T00:00:00+02:00     131
# 1     74857  Marc-André ter Stegen  2028-06-30T00:00:00+02:00     131
# 2     44058      Wojciech Szczesny  2027-06-30T00:00:00+02:00     131
# 3    962110            Pau Cubarsí  2029-06-30T00:00:00+02:00     131
# 4    466794            Eric García  2031-06-30T00:00:00+02:00     131
#
#              teamName date_of_birth   age  height preferredFoot     position  \
# 0  FC Barcelona ~ 131    2001-05-04  24.0    1.94         right   Goalkeeper
# 1  FC Barcelona ~ 131    1992-04-30  33.0    1.87         right   Goalkeeper
# 2  FC Barcelona ~ 131    1990-04-18  35.0    1.95         right   Goalkeeper
# 3  FC Barcelona ~ 131    2007-01-22  18.0    1.84         right  Centre-Back
# 4  FC Barcelona ~ 131    2001-01-09  24.0    1.82         right  Centre-Back
#
#    ...  secondSidePosition nationality  nationalityId  MarketValueCurrent  \
# 0  ...                 NaN         NaN            157          30000000.0
# 1  ...                 NaN         NaN             40           7000000.0
# 2  ...                 NaN         NaN            135            900000.0
# 3  ...                 NaN         NaN            157          80000000.0
# 4  ...  Defensive Midfield         NaN            157          30000000.0
#
#    preferredFootId  positionId  firstSidePositionId  secondSidePositionId  \
# 0                2         1.0                  NaN                   NaN
# 1                2         1.0                  NaN                   NaN
# 2                2         1.0                  NaN                   NaN
# 3                2         3.0                  NaN                   NaN
# 4                2         3.0                  5.0                   6.0
#
#    MarketValuePrevious  MarketValueCurrency
# 0           25000000.0                  EUR
# 1            8000000.0                  EUR
# 2            1000000.0                  EUR
# 3           80000000.0                  EUR
# 4           25000000.0                  EUR
#
# [5 rows x 21 columns]

# %%
print('Number of rows in bio_data:', bio_data.shape[0])
print('Number of cols in bio_data:', bio_data.shape[1])
# Out:
# Number of rows in bio_data: 8831
# Number of cols in bio_data: 21

# %%
stats_data_path = f'{data_dir}/sofascore/all_player_stats_merged.csv'
stats_data = pd.read_csv(stats_data_path)
stats_data.head()
# Out:
#              player_name date_of_birth            teamName    rating  \
# 0            Joan García    2001-05-04  FC Barcelona ~ 131  7.386842
# 1  Marc-André ter Stegen    1992-04-30  FC Barcelona ~ 131  6.812500
# 2      Wojciech Szczesny    1990-04-18  FC Barcelona ~ 131  6.913333
# 3            Pau Cubarsí    2007-01-22  FC Barcelona ~ 131  6.954286
# 4          Ronald Araujo    1999-03-07  FC Barcelona ~ 131  7.100000
#
#    totalRating  countRating  goals  bigChancesCreated  bigChancesMissed  \
# 0        280.7         38.0    0.0                0.0               0.0
# 1         54.5          8.0    0.0                0.0               0.0
# 2        103.7         15.0    0.0                0.0               0.0
# 3        243.4         35.0    0.0                3.0               1.0
# 4         85.2         12.0    1.0                1.0               1.0
#
#    assists  ...  blocks  personalFouls  steals  fieldGoalsPercentage  \
# 0        0  ...     NaN            NaN     NaN                   NaN
# 1        0  ...     NaN            NaN     NaN                   NaN
# 2        0  ...     NaN            NaN     NaN                   NaN
# 3        3  ...     NaN            NaN     NaN                   NaN
# 4        1  ...     NaN            NaN     NaN                   NaN
#
#    freeThrowsPercentage  threePointsPercentage  twoPointsPercentage  \
# 0                   NaN                    NaN                  NaN
# 1                   NaN                    NaN                  NaN
# 2                   NaN                    NaN                  NaN
# 3                   NaN                    NaN                  NaN
# 4                   NaN                    NaN                  NaN
#
#    doubleDoubles  tripleDoubles  assistTurnoverRatio
# 0            NaN            NaN                  NaN
# 1            NaN            NaN                  NaN
# 2            NaN            NaN                  NaN
# 3            NaN            NaN                  NaN
# 4            NaN            NaN                  NaN
#
# [5 rows x 139 columns]

# %%
print('Number of rows in stats_data:', stats_data.shape[0])
print('Number of cols in stats_data:', stats_data.shape[1])
# Out:
# Number of rows in stats_data: 5536
# Number of cols in stats_data: 139

# %% [markdown]
# ### Correcting and Standardizing Data Types

# %%
print(bio_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8831 entries, 0 to 8830
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   playerId              8831 non-null   int64
#  1   name                  8831 non-null   object
#  2   contractUntil         8532 non-null   object
#  3   teamId                8831 non-null   int64
#  4   teamName              8831 non-null   object
#  5   date_of_birth         8819 non-null   object
#  6   age                   8819 non-null   float64
#  7   height                8541 non-null   float64
#  8   preferredFoot         8286 non-null   object
#  9   position              8805 non-null   object
#  10  firstSidePosition     5977 non-null   object
#  11  secondSidePosition    3577 non-null   object
#  12  nationality           0 non-null      float64
#  13  nationalityId         8831 non-null   int64
#  14  MarketValueCurrent    8525 non-null   float64
#  15  preferredFootId       8831 non-null   int64
#  16  positionId            8805 non-null   float64
#  17  firstSidePositionId   5977 non-null   float64
#  18  secondSidePositionId  3577 non-null   float64
#  19  MarketValuePrevious   8361 non-null   float64
#  20  MarketValueCurrency   8525 non-null   object
# dtypes: float64(8), int64(4), object(9)
# memory usage: 1.4+ MB
# None

# %%
bio_data['contractUntil'] = pd.to_datetime(bio_data['contractUntil'], errors='coerce', utc=True)
bio_data['contractUntil'] = bio_data['contractUntil'].dt.tz_localize(None)

# %%
# Date time conversion
bio_data['date_of_birth'] = pd.to_datetime(bio_data['date_of_birth'], errors='coerce')
stats_data['date_of_birth'] = pd.to_datetime(stats_data['date_of_birth'], errors='coerce')

# %%
print(bio_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8831 entries, 0 to 8830
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   playerId              8831 non-null   int64
#  1   name                  8831 non-null   object
#  2   contractUntil         8532 non-null   datetime64[ns]
#  3   teamId                8831 non-null   int64
#  4   teamName              8831 non-null   object
#  5   date_of_birth         8819 non-null   datetime64[ns]
#  6   age                   8819 non-null   float64
#  7   height                8541 non-null   float64
#  8   preferredFoot         8286 non-null   object
#  9   position              8805 non-null   object
#  10  firstSidePosition     5977 non-null   object
#  11  secondSidePosition    3577 non-null   object
#  12  nationality           0 non-null      float64
#  13  nationalityId         8831 non-null   int64
#  14  MarketValueCurrent    8525 non-null   float64
#  15  preferredFootId       8831 non-null   int64
#  16  positionId            8805 non-null   float64
#  17  firstSidePositionId   5977 non-null   float64
#  18  secondSidePositionId  3577 non-null   float64
#  19  MarketValuePrevious   8361 non-null   float64
#  20  MarketValueCurrency   8525 non-null   object
# dtypes: datetime64[ns](2), float64(8), int64(4), object(7)
# memory usage: 1.4+ MB
# None

# %%
# Check object data types in stats_data
for col, dtype in stats_data.dtypes.items():
    if dtype == 'object':
        print(f"{col}: {dtype} (example value: {stats_data[col].dropna().iloc[0]})")
    # print(f"{col}: {dtype}")
# Out:
# player_name: object (example value: Joan García)
# teamName: object (example value: FC Barcelona ~ 131)
# type: object (example value: overall)

# %% [markdown]
# ### Handle Duplicates and Missing Values

# %%
# Check duplicates
print('Duplicates in stats_data:', stats_data.duplicated().sum())
print('Duplicates in bio_data:', bio_data.duplicated().sum())
# Out:
# Duplicates in stats_data: 0
# Duplicates in bio_data: 0

# %%
# Check missing values
for col, missing_count in bio_data.isna().sum().sort_values(ascending=False).items():
    if missing_count > 0:
        print(f"{col}: {missing_count} missing values")
# Out:
# nationality: 8831 missing values
# secondSidePosition: 5254 missing values
# secondSidePositionId: 5254 missing values
# firstSidePosition: 2854 missing values
# firstSidePositionId: 2854 missing values
# preferredFoot: 545 missing values
# MarketValuePrevious: 470 missing values
# MarketValueCurrency: 306 missing values
# MarketValueCurrent: 306 missing values
# contractUntil: 299 missing values
# height: 290 missing values
# position: 26 missing values
# positionId: 26 missing values
# age: 12 missing values
# date_of_birth: 12 missing values

# %%
# Drop nationality column
bio_data.drop(columns=['nationality'], inplace=True)
# Fill missing side positions values with 'None'
bio_data[['secondSidePosition', 'secondSidePositionId', 'firstSidePosition', 'firstSidePositionId']] = bio_data[['secondSidePosition', 'secondSidePositionId', 'firstSidePosition', 'firstSidePositionId']].fillna('None')
# bio_data['']

# %%
# Remove all players with no date_of_birth and position (since they are few)
bio_data.drop(index=bio_data[bio_data['date_of_birth'].isna()].index, inplace=True)
bio_data.drop(index=bio_data[bio_data['position'].isna()].index, inplace=True)
# Remove all players with no market_value (important column)
bio_data.drop(index=bio_data[bio_data['MarketValueCurrent'].isna()].index, inplace=True)
bio_data.drop(index=bio_data[bio_data['MarketValuePrevious'].isna()].index, inplace=True)

# %%
# Assume that players without contractUntil are free agents, fillna with a today date
bio_data['contractUntil'] = bio_data['contractUntil'].fillna(pd.to_datetime('today'))

# %%
# Fill missing preferredFoot with most common value
most_common_foot = bio_data['preferredFoot'].mode()[0]
most_common_foot_id = bio_data['preferredFootId'].mode()[0]
bio_data.loc[bio_data['preferredFoot'].isna(), 'preferredFoot'] = most_common_foot
bio_data.loc[bio_data['preferredFootId']==0, 'preferredFootId'] = most_common_foot_id

# %%
# Fill height with median values corresponding to their positions
position_groups = bio_data.groupby('position')
for position, group in position_groups:
    median_height = group['height'].median()
    bio_data.loc[(bio_data['position'] == position) & (bio_data['height'].isna()), 'height'] = median_height

# %%
# Check missing values again
missing_col = []
for col, missing_count in bio_data.isna().sum().sort_values(ascending=False).items():
    if missing_count > 0:
        print(f"{col}: {missing_count} missing values")
        missing_col.append(col)
if not missing_col:
    print("No missing values remain in bio_data.")
# Out:
# No missing values remain in bio_data.

# %%
print('Number of rows in bio_data after cleaning:', bio_data.shape[0])
print('Number of cols in bio_data after cleaning:', bio_data.shape[1])
# Out:
# Number of rows in bio_data after cleaning: 8357
# Number of cols in bio_data after cleaning: 20

# %%
drop_cols = []
for col, missing_count in stats_data.isna().sum().sort_values(ascending=False).items():
    if missing_count > 0:
        print(f"{col}: {missing_count} missing values")
        if missing_count == 5535:
            drop_cols.append(col)
# Out:
# threePointAttempts: 5535 missing values
# freeThrowsMade: 5535 missing values
# freeThrowAttempts: 5535 missing values
# assistTurnoverRatio: 5535 missing values
# tripleDoubles: 5535 missing values
# doubleDoubles: 5535 missing values
# twoPointsPercentage: 5535 missing values
# threePointsPercentage: 5535 missing values
# freeThrowsPercentage: 5535 missing values
# fieldGoalsPercentage: 5535 missing values
# steals: 5535 missing values
# personalFouls: 5535 missing values
# blocks: 5535 missing values
# turnovers: 5535 missing values
# offensiveRebounds: 5535 missing values
# defensiveRebounds: 5535 missing values
# rebounds: 5535 missing values
# fieldGoalAttempts: 5535 missing values
# fieldGoalsMade: 5535 missing values
# twoPointAttempts: 5535 missing values
# twoPointsMade: 5535 missing values
# points: 5535 missing values
# threePointsMade: 5535 missing values
# secondsPlayed: 5535 missing values
# goalsPrevented: 5136 missing values
# outfielderBlocks: 4874 missing values
# expectedGoals: 1375 missing values
# expectedAssists: 701 missing values
# date_of_birth: 2 missing values
# cleanSheet: 1 missing values
# blockedShots: 1 missing values
# countRating: 1 missing values
# goals: 1 missing values
# bigChancesCreated: 1 missing values
# bigChancesMissed: 1 missing values
# totalRating: 1 missing values
# saves: 1 missing values
# passToAssist: 1 missing values
# goalsAssistsSum: 1 missing values
# accuratePassesPercentage: 1 missing values
# accurateOwnHalfPasses: 1 missing values
# inaccuratePasses: 1 missing values
# accuratePasses: 1 missing values
# penaltyWon: 1 missing values
# penaltyConceded: 1 missing values
# freeKickGoal: 1 missing values
# shotFromSetPiece: 1 missing values
# goalsFromOutsideTheBox: 1 missing values
# shotsFromInsideTheBox: 1 missing values
# accurateOppositionHalfPasses: 1 missing values
# totalPasses: 1 missing values
# keyPasses: 1 missing values
# successfulDribbles: 1 missing values
# successfulDribblesPercentage: 1 missing values
# tackles: 1 missing values
# interceptions: 1 missing values
# yellowCards: 1 missing values
# directRedCards: 1 missing values
# accurateFinalThirdPasses: 1 missing values
# accurateCrosses: 1 missing values
# accurateCrossesPercentage: 1 missing values
# totalShots: 1 missing values
# shotsOnTarget: 1 missing values
# shotsOffTarget: 1 missing values
# groundDuelsWon: 1 missing values
# groundDuelsWonPercentage: 1 missing values
# aerialDuelsWon: 1 missing values
# aerialDuelsWonPercentage: 1 missing values
# totalDuelsWon: 1 missing values
# totalDuelsWonPercentage: 1 missing values
# minutesPlayed: 1 missing values
# goalConversionPercentage: 1 missing values
# penaltiesTaken: 1 missing values
# penaltyGoals: 1 missing values
# redCards: 1 missing values
# totalOppositionHalfPasses: 1 missing values
# totalOwnHalfPasses: 1 missing values
# savesParried: 1 missing values
# savesCaught: 1 missing values
# dribbledPast: 1 missing values
# offsides: 1 missing values
# ownGoals: 1 missing values
# hitWoodwork: 1 missing values
# accurateChippedPasses: 1 missing values
# fouls: 1 missing values
# wasFouled: 1 missing values
# touches: 1 missing values
# possessionWonAttThird: 1 missing values
# totalChippedPasses: 1 missing values
# possessionLost: 1 missing values
# dispossessed: 1 missing values
# headedGoals: 1 missing values
# errorLeadToShot: 1 missing values
# errorLeadToGoal: 1 missing values
# clearances: 1 missing values
# accurateLongBallsPercentage: 1 missing values
# accurateLongBalls: 1 missing values
# rightFootGoals: 1 missing values
# leftFootGoals: 1 missing values
# goalsFromInsideTheBox: 1 missing values
# shotsFromOutsideTheBox: 1 missing values
# penaltyFaced: 1 missing values
# penaltySave: 1 missing values
# goalsConcededInsideTheBox: 1 missing values
# goalsConcededOutsideTheBox: 1 missing values
# savedShotsFromInsideTheBox: 1 missing values
# savedShotsFromOutsideTheBox: 1 missing values
# totalContest: 1 missing values
# totalAttemptAssist: 1 missing values
# setPieceConversion: 1 missing values
# penaltyConversion: 1 missing values
# yellowRedCards: 1 missing values
# scoringFrequency: 1 missing values
# tacklesWonPercentage: 1 missing values
# tacklesWon: 1 missing values
# goalsConceded: 1 missing values
# totalLongBalls: 1 missing values
# attemptPenaltyTarget: 1 missing values
# attemptPenaltyPost: 1 missing values
# attemptPenaltyMiss: 1 missing values
# aerialLost: 1 missing values
# duelLost: 1 missing values
# totalCross: 1 missing values
# runsOut: 1 missing values
# punches: 1 missing values
# goalKicks: 1 missing values
# totwAppearances: 1 missing values
# matchesStarted: 1 missing values
# crossesNotClaimed: 1 missing values
# highClaims: 1 missing values
# successfulRunsOut: 1 missing values
# ballRecovery: 1 missing values

# %%
# Drop columns with too many missing values
stats_data.drop(columns=drop_cols, inplace=True)

# %%
# Remove rows with missing important values
stats_data.drop(index=stats_data[stats_data['cleanSheet'].isna()].index, inplace=True)

# %%
# Remove rows with missing date_of_birth (since they are few)
stats_data.drop(index=stats_data[stats_data['date_of_birth'].isna()].index, inplace=True)

# %%
# Players with no expected goals/assists get 0 since they might be defenders or goalkeepers
stats_data[['expectedGoals', 'expectedAssists']] = stats_data[['expectedGoals', 'expectedAssists']].fillna(0)

# %%
# Players without goalsPrevented might not be goalkeepers, fillna with 0
stats_data[['goalsPrevented']] = stats_data[['goalsPrevented']].fillna(0)

# %%
# Drop outfielderBlocks since this statistic may only be recorded for some leagues
stats_data.drop(columns=['outfielderBlocks'], inplace=True)

# %%
# Check missing values again
missing_col = []
for col, missing_count in stats_data.isna().sum().sort_values(ascending=False).items():
    if missing_count > 0:
        print(f"{col}: {missing_count} missing values")
        missing_col.append(col)
if len(missing_col) == 0:
    print('No missing values in stats_data')
# Out:
# No missing values in stats_data

# %% [markdown]
# ### Merge Datasets

# %%
# Find similar columns in two datasets
common_cols = set(bio_data.columns).intersection(set(stats_data.columns))
print('Common columns in both datasets:', common_cols)
# Out:
# Common columns in both datasets: {'teamName', 'date_of_birth'}

# %%
merged_data = pd.merge(bio_data, stats_data, left_on=['name', 'teamName', 'date_of_birth'], right_on=['player_name', 'teamName', 'date_of_birth'], how='inner')
merged_data.head()
# Out:
#    playerId                   name       contractUntil  teamId  \
# 0    561613            Joan García 2031-06-29 22:00:00     131
# 1     74857  Marc-André ter Stegen 2028-06-29 22:00:00     131
# 2     44058      Wojciech Szczesny 2027-06-29 22:00:00     131
# 3    962110            Pau Cubarsí 2029-06-29 22:00:00     131
# 4    466794            Eric García 2031-06-29 22:00:00     131
#
#              teamName date_of_birth   age  height preferredFoot     position  \
# 0  FC Barcelona ~ 131    2001-05-04  24.0    1.94         right   Goalkeeper
# 1  FC Barcelona ~ 131    1992-04-30  33.0    1.87         right   Goalkeeper
# 2  FC Barcelona ~ 131    1990-04-18  35.0    1.95         right   Goalkeeper
# 3  FC Barcelona ~ 131    2007-01-22  18.0    1.84         right  Centre-Back
# 4  FC Barcelona ~ 131    2001-01-09  24.0    1.82         right  Centre-Back
#
#    ... savesParried totalOwnHalfPasses  totalOppositionHalfPasses  \
# 0  ...         21.0              625.0                      434.0
# 1  ...          1.0              184.0                       27.0
# 2  ...          6.0              345.0                       46.0
# 3  ...          0.0             1498.0                     1095.0
# 4  ...          0.0              573.0                      721.0
#
#    totwAppearances  expectedGoals  goalKicks ballRecovery       id     type  \
# 0              7.0         0.0741      216.0        392.0  1519597  overall
# 1              0.0         0.0000       27.0         59.0  1513902  overall
# 2              0.0         0.0000       54.0        122.0  1794211  overall
# 3              2.0         0.8260       10.0        102.0  1513933  overall
# 4              0.0         2.3181        1.0         54.0  1513895  overall
#
#   appearances
# 0          38
# 1           8
# 2          15
# 3          35
# 4          29
#
# [5 rows x 132 columns]

# %%
for col, dtype in merged_data.dtypes.items():
    print(f"{col}: {dtype}")
    # print(f"{col}: {dtype}")
# Out:
# playerId: int64
# name: object
# contractUntil: datetime64[ns]
# teamId: int64
# teamName: object
# date_of_birth: datetime64[ns]
# age: float64
# height: float64
# preferredFoot: object
# position: object
# firstSidePosition: object
# secondSidePosition: object
# nationalityId: int64
# MarketValueCurrent: float64
# preferredFootId: int64
# positionId: float64
# firstSidePositionId: object
# secondSidePositionId: object
# MarketValuePrevious: float64
# MarketValueCurrency: object
# player_name: object
# rating: float64
# totalRating: float64
# countRating: float64
# goals: float64
# bigChancesCreated: float64
# bigChancesMissed: float64
# assists: int64
# expectedAssists: float64
# goalsAssistsSum: float64
# accuratePasses: float64
# inaccuratePasses: float64
# totalPasses: float64
# accuratePassesPercentage: float64
# accurateOwnHalfPasses: float64
# accurateOppositionHalfPasses: float64
# accurateFinalThirdPasses: float64
# keyPasses: float64
# successfulDribbles: float64
# successfulDribblesPercentage: float64
# tackles: float64
# interceptions: float64
# yellowCards: float64
# directRedCards: float64
# redCards: float64
# accurateCrosses: float64
# accurateCrossesPercentage: float64
# totalShots: float64
# shotsOnTarget: float64
# shotsOffTarget: float64
# groundDuelsWon: float64
# groundDuelsWonPercentage: float64
# aerialDuelsWon: float64
# aerialDuelsWonPercentage: float64
# totalDuelsWon: float64
# totalDuelsWonPercentage: float64
# minutesPlayed: float64
# goalConversionPercentage: float64
# penaltiesTaken: float64
# penaltyGoals: float64
# penaltyWon: float64
# penaltyConceded: float64
# shotFromSetPiece: float64
# freeKickGoal: float64
# goalsFromInsideTheBox: float64
# goalsFromOutsideTheBox: float64
# shotsFromInsideTheBox: float64
# shotsFromOutsideTheBox: float64
# headedGoals: float64
# leftFootGoals: float64
# rightFootGoals: float64
# accurateLongBalls: float64
# accurateLongBallsPercentage: float64
# clearances: float64
# errorLeadToGoal: float64
# errorLeadToShot: float64
# dispossessed: float64
# possessionLost: float64
# possessionWonAttThird: float64
# totalChippedPasses: float64
# accurateChippedPasses: float64
# touches: float64
# wasFouled: float64
# fouls: float64
# hitWoodwork: float64
# ownGoals: float64
# dribbledPast: float64
# offsides: float64
# blockedShots: float64
# passToAssist: float64
# saves: float64
# goalsPrevented: float64
# cleanSheet: float64
# penaltyFaced: float64
# penaltySave: float64
# savedShotsFromInsideTheBox: float64
# savedShotsFromOutsideTheBox: float64
# goalsConcededInsideTheBox: float64
# goalsConcededOutsideTheBox: float64
# punches: float64
# runsOut: float64
# successfulRunsOut: float64
# highClaims: float64
# crossesNotClaimed: float64
# matchesStarted: float64
# penaltyConversion: float64
# setPieceConversion: float64
# totalAttemptAssist: float64
# totalContest: float64
# totalCross: float64
# duelLost: float64
# aerialLost: float64
# attemptPenaltyMiss: float64
# attemptPenaltyPost: float64
# attemptPenaltyTarget: float64
# totalLongBalls: float64
# goalsConceded: float64
# tacklesWon: float64
# tacklesWonPercentage: float64
# scoringFrequency: float64
# yellowRedCards: float64
# savesCaught: float64
# savesParried: float64
# totalOwnHalfPasses: float64
# totalOppositionHalfPasses: float64
# totwAppearances: float64
# expectedGoals: float64
# goalKicks: float64
# ballRecovery: float64
# id: int64
# type: object
# appearances: int64

# %%
merged_data.describe()
# Out:
#            playerId                  contractUntil         teamId  \
# count  5.466000e+03                           5466    5466.000000
# mean   5.298580e+05  2027-10-01 04:19:39.709324032    6109.077936
# min    3.333000e+03            2025-06-21 22:00:00       3.000000
# 25%    3.072615e+05            2026-06-29 22:00:00     333.000000
# 50%    4.911685e+05            2027-06-29 22:00:00     982.000000
# 75%    7.166360e+05            2028-06-29 22:00:00    3057.000000
# max    1.396595e+06            2035-06-29 22:00:00  114977.000000
# std    2.941924e+05                            NaN   16275.462617
#
#                        date_of_birth          age       height  nationalityId  \
# count                           5466  5466.000000  5466.000000    5466.000000
# mean   1999-03-20 16:07:38.397365632    26.198866     1.823734      93.189352
# min              1982-02-13 00:00:00    16.000000     1.560000       2.000000
# 25%              1996-03-13 00:00:00    23.000000     1.780000      33.000000
# 50%              1999-09-17 00:00:00    26.000000     1.830000      77.000000
# 75%              2002-08-09 00:00:00    29.000000     1.880000     157.000000
# max              2009-07-10 00:00:00    43.000000     2.060000     260.000000
# std                              NaN     4.532587     0.068575      66.276464
#
#        MarketValueCurrent  preferredFootId   positionId  ...  savesCaught  \
# count        5.466000e+03      5466.000000  5466.000000  ...  5466.000000
# mean         6.906458e+06         1.777351     7.049396  ...     0.034211
# min          0.000000e+00         1.000000     1.000000  ...     0.000000
# 25%          7.000000e+05         2.000000     3.000000  ...     0.000000
# 50%          2.000000e+06         2.000000     6.000000  ...     0.000000
# 75%          6.000000e+06         2.000000    11.000000  ...     0.000000
# max          2.000000e+08         3.000000    14.000000  ...     4.000000
# std          1.387776e+07         0.477113     4.134709  ...     0.243714
#
#        savesParried  totalOwnHalfPasses  totalOppositionHalfPasses  \
# count   5466.000000         5466.000000                5466.000000
# mean       0.896634          297.769118                 356.224844
# min        0.000000            0.000000                   0.000000
# 25%        0.000000           72.000000                 122.000000
# 50%        0.000000          191.500000                 291.000000
# 75%        0.000000          439.000000                 524.750000
# max       40.000000         2527.000000                2442.000000
# std        3.950392          307.671335                 297.014472
#
#        totwAppearances  expectedGoals    goalKicks  ballRecovery  \
# count      5466.000000    5466.000000  5466.000000   5466.000000
# mean          0.815221       1.769932    11.392609     69.894804
# min           0.000000       0.000000     0.000000      0.000000
# 25%           0.000000       0.015925     0.000000     25.000000
# 50%           0.000000       0.669300     0.000000     57.000000
# 75%           1.000000       2.114875     0.000000     99.000000
# max          16.000000      30.950000   348.000000    431.000000
# std           1.481905       2.968643    40.112644     60.876177
#
#                  id  appearances
# count  5.466000e+03  5466.000000
# mean   1.592132e+06    21.352726
# min    1.349303e+06     1.000000
# 25%    1.492218e+06    13.000000
# 50%    1.518176e+06    23.000000
# 75%    1.673328e+06    30.000000
# max    2.480613e+06    46.000000
# std    1.754557e+05    10.959210
#
# [8 rows x 121 columns]

# %%
# Save cleaned data
merged_data.to_csv('cleaned_player_data.csv', index=False)
